# %%
import os
import pandas as pd
import numpy as np

import seaborn as sns


sns.set()

import matplotlib.pyplot as plt
sns.set_style('darkgrid')
import researchpy as rchpy

# %%
#print curent dir
print("Current Working Directory " , os.getcwd())
# Out:
# Current Working Directory  c:\Users\jongala\Dropbox\NUST\NUST-Teaching and Research\Africa data school\Assignments\ADS-Assignment-4

# %%
df = pd.read_csv ('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %% [markdown]
# 1. QUESTION 1 (Part a)

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5), sharey=True)
fig.suptitle('Effect on Demographics')
sns.countplot(ax=axes[0] ,   x ='gender', data = df)
axes[0].set_title("gender")
sns.countplot(ax=axes[1] ,   x ='SeniorCitizen',  data = df)
axes[1].set_title("Senior Citizen")
sns.countplot(ax=axes[2] ,   x ='Partner',  data = df)
axes[2].set_title("Partner")
sns.countplot(ax=axes[3] ,   x ='Dependents',  data = df)
axes[3].set_title("Dependents")
# Out:
# Text(0.5, 1.0, 'Dependents')

# %% [markdown]
# Ans: Senior Citiczen and customers with dependants

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5), sharey=True)
fig.suptitle('Effect on churn')
sns.countplot(ax=axes[0] ,   x ='gender', hue = "Churn", data = df)
axes[0].set_title("gender")
sns.countplot(ax=axes[1] ,   x ='SeniorCitizen', hue = "Churn", data = df)
axes[1].set_title("Senior Citizen")
sns.countplot(ax=axes[2] ,   x ='Partner', hue = "Churn", data = df)
axes[2].set_title("Partner")
sns.countplot(ax=axes[3] ,   x ='Dependents', hue = "Churn", data = df)
axes[3].set_title("Dependents")
# Out:
# Text(0.5, 1.0, 'Dependents')

# %%
g = sns.FacetGrid(df, col="gender",  row="Partner", hue = "SeniorCitizen")
g.map(sns.countplot,  "Churn")
g.add_legend()
# Out:
# C:\Users\jongala\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Answer: Senior citizens

# %% [markdown]
# df.dtypes

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# 2. QUESTION TWO PART A

# %%
fig, axes = plt.subplots(1, 7, figsize=(20, 5), sharey=True)
fig.suptitle('Services')

sns.barplot(ax=axes[0], x='PhoneService', y='MonthlyCharges', hue='Churn', data=df, palette='hls')
axes[0].set_title('Phone Service')

df1=df[df.InternetService!="No"]

sns.barplot(ax=axes[1], x='StreamingMovies', y='MonthlyCharges', hue='Churn', data=df1, palette='hls')
axes[1].set_title('Streaming Movies')



sns.barplot(ax=axes[2], x='OnlineSecurity', y='MonthlyCharges', hue='Churn', data=df1, palette='hls')
axes[2].set_title('Online Security')

sns.barplot(ax=axes[3], x='OnlineBackup', y='MonthlyCharges', hue='Churn', data=df1, palette='hls')
axes[3].set_title('Online Backup')

sns.barplot(ax=axes[4], x='DeviceProtection', y='MonthlyCharges', hue='Churn', data=df1, palette='hls')
axes[4].set_title('Device Protection')

sns.barplot(ax=axes[5], x='TechSupport', y='MonthlyCharges', hue='Churn', data=df1, palette='hls')
axes[5].set_title('Tech Support')

sns.barplot(ax=axes[6], x='StreamingTV', y='MonthlyCharges', hue='Churn', data=df1, palette='hls')
axes[6].set_title('StreamingTV ')
# Out:
# Text(0.5, 1.0, 'StreamingTV ')

# %% [markdown]
# Ans: Streaming Movies, Device protection and streaming TV

# %%
pd.crosstab(df.PhoneService, df.Contract)
# Out:
# Contract      Month-to-month  One year  Two year
# PhoneService
# No                       376       145       161
# Yes                     3499      1328      1534

# %%
df2=df[df.PhoneService=="Yes"]

# %%
sns.countplot( x='Contract', hue='Churn', data=df2)
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %%
pd.crosstab(df2['Contract'],df2['Churn'])
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  1997  1502
# One year        1176   152
# Two year        1489    45

# %%
rchpy.crosstab(df2['Contract'],df2['Churn'],  prop= "row")
# Out:
#                 Churn
# Churn              No    Yes    All
# Contract
# Month-to-month  57.07  42.93  100.0
# One year        88.55  11.45  100.0
# Two year        97.07   2.93  100.0
# All             73.29  26.71  100.0

# %% [markdown]
# Ans: Two Year Contruct

# %% [markdown]
# QUESTION 3

# %%
missing_value= ['n/a','na','--', '-', ' ', '','nan','NaN','NAN','Nan','naN']
df=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv", na_values = missing_value)

# %%
df.MonthlyCharges.dtypes
# Out:
# dtype('float64')

# %%
sns.boxplot( y='MonthlyCharges', x='Churn', data=df)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='MonthlyCharges'>

# %%
df[df.Churn=="No"].MonthlyCharges.describe()
# Out:
# count    5174.000000
# mean       61.265124
# std        31.092648
# min        18.250000
# 25%        25.100000
# 50%        64.425000
# 75%        88.400000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# ANS:
# i. Basic =64.4
# ii. Plus =88.4
# iii. Premium =120

# %%
df.PaperlessBilling

# %%
sns.countplot( x='PaperlessBilling', hue='Churn', data=df)
# Out:
# <AxesSubplot:xlabel='PaperlessBilling', ylabel='count'>

# %% [markdown]
# ANS: No, They should not go strictly paperless since, the results indicate thatthose who go paperless has a higher proportion of churning
